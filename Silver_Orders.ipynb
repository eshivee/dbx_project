# %%
df = spark.read.format('parquet').load('abfss://bronze@etedbxcrop.dfs.core.windows.net/orders')

# %%
df = df.drop("_rescued_data")
df.display()

# %%
df.write.format('delta').mode('append').save('abfss://silver@etedbxcrop.dfs.core.windows.net/orders')
