# %%
df = spark.read.table('dbx_cata.bronze.regions')

# %%
df = df.drop('_rescued_data')
df.display()

# %%
df.write.format('delta').mode('overwrite').save('abfss://silver@etedbxcrop.dfs.core.windows.net/regions')

# %%
# %sql
CREATE TABLE IF NOT EXISTS dbx_cata.silver.regions
USING DELTA
LOCATION 'abfss://silver@etedbxcrop.dfs.core.windows.net/regions'

# %%
# %sql
SELECT * FROM dbx_cata.silver.regions
